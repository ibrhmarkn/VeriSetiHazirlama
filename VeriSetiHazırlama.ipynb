# %%
import numpy as np # Matematiksel lineer işlemler için
import pandas as pd  # veri ekleme veriseti oluşturma 
import matplotlib.pyplot as plt #görselleştirme
import seaborn as sns # görselleştirme

# %%
data = pd.read_csv('pokemon.csv') # veriyi ekleme

# %%
print(data.head()) # verinin ilk 5 tane görünümü
print(data.info()) # veriseti bilgisi
# Out:
#    #           Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2        Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3       Venusaur  Grass  Poison  ...      100     80           1      False
# 3  4  Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  5     Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
# ...

# %% [markdown]
# #Korelasyon Matrisi verilerin arasındaki ilişkilerini temsil eder
# #Örnek olarak bir evin fiyatı ile oda sayısı pozitif ilişkili bir korelasyondur.

# %%
f,ax = plt.subplots(figsize=(13,13))
sns.heatmap(data.corr(),annot=True, linewidths=2, fmt='.1f',ax=ax)

# %%
data.corr()
# Out:
#                    #        HP    Attack  ...     Speed  Generation  Legendary
# #           1.000000  0.097712  0.102664  ...  0.012181    0.983428   0.154336
# HP          0.097712  1.000000  0.422386  ...  0.175952    0.058683   0.273620
# Attack      0.102664  0.422386  1.000000  ...  0.381240    0.051451   0.345408
# Defense     0.094691  0.239622  0.438687  ...  0.015227    0.042419   0.246377
# Sp. Atk     0.089199  0.362380  0.396362  ...  0.473018    0.036437   0.448907
# Sp. Def     0.085596  0.378718  0.263990  ...  0.259133    0.028486   0.363937
# Speed       0.012181  0.175952  0.381240  ...  1.000000   -0.023121   0.326715
# Generation  0.983428  0.058683  0.051451  ... -0.023121    1.000000   0.079794
# Legendary   0.154336  0.273620  0.345408  ...  0.326715    0.079794   1.000000
#
# [9 rows x 9 columns]

# %%
data.columns # Veri setinin sahip olduğu öznitelikler
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.Speed.plot(kind='line',color='blue',label = 'Speed',linewidth = 1, alpha=0.5,grid = True,linestyle=':')
data.Defense.plot(color='red',label = 'Defense',linewidth = 1, alpha=0.5,grid = True,linestyle='-')
plt.legend(loc='upper right')
plt.xlabel('Pokemonlar')
plt.ylabel('Hız ve Defans Gücü')
# Out:
# Text(0, 0.5, 'Hız ve Defans Gücü')

# %% [markdown]
# #scatter plotter korelasyon ilişkisini görmek için kullanılır genel olarak

# %%
data.plot(kind='scatter',x = 'Attack',y='Defense',alpha=0.5, color='blue')
plt.xlabel('Atak')
plt.ylabel('Defans')
plt.title('Atak ve Defans korelasyonu')

# Görsele baktığımız zaman atak arttığı zaman defans da artar
# Out:
# Text(0.5, 1.0, 'Atak ve Defans korelasyonu')

# %% [markdown]
# #Histogram
# # Tek değeri data net görebilmek için frekansına bakabilmek için kullanılır.

# %%
data.Speed.plot(kind='hist',bins = 50,figsize=(13,13))
plt.show()

# %% [markdown]
# # dictionary bize key ve value değerleri ile bir dataframe oluşturma kolaylıpı sunar
# # dic = {'Türkiye':'Ankara'}

# %%
dic = {'Türkiye':'Ankara'}
print(dic.keys())
print(dic.values())
# Out:
# dict_keys(['Türkiye'])
# dict_values(['Ankara'])

# %% [markdown]
# Csv formatı virgül ile ayrılmış veriler şeklidir.

# %% [markdown]
# Seriler ve DataFrame kullanılar veri tipleridir.
# Seriler vektörel ve tek boyutlu.

# %%
series = data['Defense']
print("Seri:",series,"Tipi:",type(series))
# Out:
# Seri: 0       49
# 1       63
# 2       83
# 3      123
# 4       43
#       ...
# 795    150
# 796    110
# 797     60
# 798     60
# 799    120
# Name: Defense, Length: 800, dtype: int64 Tipi: <class 'pandas.core.series.Series'>

# %%
data_frame = data[['Defense']]
data_frame
# Out:
#      Defense
# 0         49
# 1         63
# 2         83
# 3        123
# 4         43
# ..       ...
# 795      150
# 796      110
# 797       60
# 798       60
# 799      120
#
# [800 rows x 1 columns]

# %% [markdown]
# Pandas kütüphanesi veri seti üzerinde filtreleme özelliğini kullanmamıza izin verir.

# %%
x = data['Defense']<10
data[x]
# Out:
#        #     Name  Type 1 Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 121  122  Chansey  Normal    NaN  ...      105     50           1      False
# 488  489  Happiny  Normal    NaN  ...       65     30           4      False
#
# [2 rows x 12 columns]

# %% [markdown]
# Mantıksal filtrelemeler.

# %%
data[np.logical_and(data['Defense']>200,data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 224  225  Mega Steelix  Steel  Ground  ...       95     30           2      False
# 333  334   Mega Aggron  Steel     NaN  ...       80     50           3      False
#
# [2 rows x 12 columns]

# %%
for index, value in data[['Attack']][0:1].iterrows():
  print(index,":",value)
# Out:
# 0 : Attack    49
# Name: 0, dtype: int64

# %%
def f(**kwargs):
  for key,value in kwargs.items():
    print(key,"",value)

f(country='spain',başkent='madrid')
# Out:
# country  spain
# başkent  madrid

# %% [markdown]
# lambda fonksiyonu bize fonksiyon tanımlamamızın kısa yolunu verir

# %%
square = lambda x: x**2
print(square(5))
# Out:
# 25

# %%
number_list = [1,25,45]
y = map(lambda x: x**2, number_list)
print(list(y))
# Out:
# [1, 625, 2025]

# %%
num_1 = [1,2,3]
num_2 = [i+1 for i in num_1]
print(num_2)
# Out:
# [2, 3, 4]

# %%
threshold  = sum(data.Speed)/len(data.Speed)
data["Speed Level"] = [ "high" if i>threshold else "low" for i in data.Speed ]
data[["Speed Level", "Speed"]]
# Out:
#     Speed Level  Speed
# 0           low     45
# 1           low     60
# 2          high     80
# 3          high     80
# 4           low     65
# ..          ...    ...
# 795         low     50
# 796        high    110
# 797        high     70
# 798        high     80
# 799        high     70
#
# [800 rows x 2 columns]

# %% [markdown]
# VERİ TEMİZLEME AŞAMASINA GELDİK

# %%
data = pd.read_csv('pokemon.csv')
data.head()
# Out:
#    #           Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2        Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3       Venusaur  Grass  Poison  ...      100     80           1      False
# 3  4  Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  5     Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 12 columns]

# %%
print(data['Type 1'].value_counts(dropna = False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe()
# Out:
#               #          HP      Attack  ...     Sp. Def       Speed  Generation
# count  800.0000  800.000000  800.000000  ...  800.000000  800.000000   800.00000
# mean   400.5000   69.258750   79.001250  ...   71.902500   68.277500     3.32375
# std    231.0844   25.534669   32.457366  ...   27.828916   29.060474     1.66129
# min      1.0000    1.000000    5.000000  ...   20.000000    5.000000     1.00000
# 25%    200.7500   50.000000   55.000000  ...   50.000000   45.000000     2.00000
# 50%    400.5000   65.000000   75.000000  ...   70.000000   65.000000     3.00000
# 75%    600.2500   80.000000  100.000000  ...   90.000000   90.000000     5.00000
# max    800.0000  255.000000  190.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 8 columns]

# %%
data.boxplot(column ='Attack',by = 'Legendary')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
data_new  =data.head()

# %%
melted_data = pd.melt(frame = data_new,id_vars='Name',value_vars=['Attack','Defense'])
melted_data
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %%
melted_data.pivot(index = 'Name', columns='variable',values  ='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %%
data1 = data.head()
data2 = data.tail()
data_concaneted = pd.concat([data1,data2],axis = 0,ignore_index=True)
data_concaneted
# Out:
#      #            Name   Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0    1       Bulbasaur    Grass  Poison  ...       65     45           1      False
# 1    2         Ivysaur    Grass  Poison  ...       80     60           1      False
# 2    3        Venusaur    Grass  Poison  ...      100     80           1      False
# 3    4   Mega Venusaur    Grass  Poison  ...      120     80           1      False
# 4    5      Charmander     Fire     NaN  ...       50     65           1      False
# 5  796         Diancie     Rock   Fairy  ...      150     50           6       True
# 6  797    Mega Diancie     Rock   Fairy  ...      110    110           6       True
# 7  798  Hoopa Confined  Psychic   Ghost  ...      130     70           6       True
# 8  799   Hoopa Unbound  Psychic    Dark  ...      130     80           6       True
# 9  800       Volcanion     Fire   Water  ...       90     70           6       True
#
# [10 rows x 12 columns]

# %%
data1= data['Attack'].head()
data2 = data['Defense'].head()
conc_data_col = pd.concat([data1,data2],axis=1)
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# Veri tipi çevirme

# %%
data['Type 1'] = data['Type 1'].astype('category')
data['Speed'] = data['Speed'].astype('float')
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
data['Type 1'].head()
# Out:
# 0    Grass
# 1    Grass
# 2    Grass
# 3    Grass
# 4     Fire
# Name: Type 1, dtype: category
# Categories (18, object): ['Bug', 'Dark', 'Dragon', 'Electric', ..., 'Psychic', 'Rock', 'Steel',
#                           'Water']

# %% [markdown]
# Eksik veriler

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    category
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 65.0+ KB

# %%
data['Type 2'].value_counts(dropna =False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Rock         14
# Water        14
# Ice          14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data1 = data
data1['Type 2'].dropna(inplace=True)
